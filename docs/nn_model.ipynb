# %% [raw]
# ---
# title: "Neural Network Model"
# format:
#   html:
#     code-fold: true
# jupyter: python3
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
from display_data import plot_fit_and_forecast, table_horizontal, plot_sample_data, plot_nn_loss

# %% [markdown]
# ## Latest stock values for analysis
#
# * We are using values from IBEX ticker values (Spanish stock values) every Friday - Closing
# * These are the lates values we used for our analysis.

# %%
plot_sample_data(path='modelled_fitted_data.csv', column='Close')
# Out:
#               Close
# Date
# 2024-05-23  11246.0
# 2024-05-30  11322.0
# 2024-06-06  11404.9
# 2024-06-13  10992.3
# 2024-06-20  11032.3

# %% [markdown]
# ## Test over last 8 weeks
#
# 1. We keep data from last 8 weeks 'unseen' by our arima model. <br><br>
# 2. This means that the model doesn't know the last 8 values. The hypothetical present of our model is 8 weeks in the past. <br><br>
# 3. In that hypothetical present, if we could see the future we would see the last 8 weeks.

# %%
table_horizontal(path='modelled_fitted_data.csv', column='Close', display_weeks=16)
# Out:
# Date                  2024-03-07 2024-03-14 2024-03-21 2024-03-28 2024-04-04  \
# if we knew the future    10305.7    10597.9    10943.2    11074.6    10916.0
# hypothetical present     10305.7    10597.9    10943.2    11074.6    10916.0
#
# Date                  2024-04-11 2024-04-18 2024-04-25 2024-05-02 2024-05-09  \
# if we knew the future    10686.0    10729.5    11154.6    10854.7    11105.5
# hypothetical present     10686.0    10729.5    11154.6          ?          ?
#
# Date                  2024-05-16 2024-05-23 2024-05-30 2024-06-06 2024-06-13  \
# if we knew the future    11327.7    11246.0    11322.0    11404.9    10992.3
# hypothetical present           ?          ?          ?          ?          ?
#
# Date                  2024-06-20
# if we knew the future    11032.3
# hypothetical present           ?

# %% [markdown]
# ## Plot real vales vs model output and confidence intervals
#
# This is a plot of the real values (in blue) and the model output (in green) and the confident intervals (in red)

# %%
plot_fit_and_forecast(path='modelled_fitted_data.csv', column='Close', model='nn_model',  display_weeks=16)

# %% [markdown]
# ## Further details on the model
#
# This is a plot of training loss - mae (in blue) and validation loss - mae (in red) with epochs

# %%
plot_nn_loss(path='nn_checkpoint/history.csv')
