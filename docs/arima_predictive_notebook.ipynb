# %% [raw]
# ---
# title: "Arima Predictions"
# format:
#   html:
#     code-fold: true
# jupyter: python3
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
from settings.display_data import plot_fit_and_forecast, table_horizontal, plot_sample_data, plot_predictions

# %% [markdown]
# ## Latest stock values for analysis
#
# * We are using values from IBEX ticker values (Spanish stock values) every Friday - Closing
# * These are the lates values we used for our analysis.

# %%
plot_sample_data(path='docs/modelled_fitted_data.csv', column='Close')
# Out:
#               Close
# Date
# 2024-12-13  11752.1
# 2024-12-20  11467.3
# 2024-12-27  11531.6
# 2025-01-03  11651.6
# 2025-01-10  11720.9

# %% [markdown]
# ## Predictions over future 8 weeks
#
# * We will use our model to make **ACTUAL PREDICTIONS** for 8 weeks in the future.

# %%
plot_predictions(path='docs/predictive_data.csv', column='Close', model='arima', display_weeks=16)
